# %% [markdown]
# <a href="https://colab.research.google.com/github/cturner07/Python-for-Data-Story-Telling/blob/main/Data_Story_Telling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
